# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame(np.arange(0,20).reshape(5,4),index=["Row1","Row2","Row3","Row4","Row5"],columns=["co1","co2","co3","co4"])
df.head()
# Out:
#       co1  co2  co3  co4
# Row1    0    1    2    3
# Row2    4    5    6    7
# Row3    8    9   10   11
# Row4   12   13   14   15
# Row5   16   17   18   19

# %%
df.to_csv("test1.csv")

# %%
#accessing the elements either by .iloc or loc
df.loc["Row1"]
# Out:
# co1    0
# co2    1
# co3    2
# co4    3
# Name: Row1, dtype: int64

# %%
type(df.loc["Row1"])
# Out:
# pandas.core.series.Series

# %%
#data series is any one row\column but dataframe is atleast one row and one column
df.iloc[:,:]
# Out:
#       co1  co2  co3  co4
# Row1    0    1    2    3
# Row2    4    5    6    7
# Row3    8    9   10   11
# Row4   12   13   14   15
# Row5   16   17   18   19

# %%
df.iloc[0:3,0:2]
# Out:
#       co1  co2
# Row1    0    1
# Row2    4    5
# Row3    8    9

# %%
type(df.iloc[0:1,0])
# Out:
# pandas.core.series.Series
